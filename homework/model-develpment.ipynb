# %%
import pandas as pd

# %%
df_credit_req = pd.read_csv("../files/input/solicitudes_de_credito.csv", sep=";", index_col=0)
df_credit_req.sample(5)
# Out:
#            sexo tipo_de_emprendimiento idea_negocio                 barrio  \
# 9485   femenino               servicio   peluqueria   SANTO DOMINGO SAVIO
# 3221   femenino              industria  fabrica_de_  cabecera san antonio
# 41    masculino              INDUSTRIA  fabrica de                   belen
# 9904  masculino               SERVICIO     barberia                popular
# 9097   FEMENINO               servicio   variedades        san javier no.1
#
#       estrato  comuna_ciudadano fecha_de_beneficio monto_del_credito  \
# 9485        1               1.0          3/10/2018           3000000
# 3221        3              80.0         27/09/2017           7000000
# 41          2              16.0         24/05/2016           6500000
# 9904        1               1.0          1/06/2017           7377000
# 9097        2              13.0         28/03/2017           7370000
#
#          línea_credito
# 9485  microempresarial
# 3221  microempresarial
# 41    microempresarial
# 9904  microempresarial
# 9097  microempresarial

# %%
df_credit_req = df_credit_req.dropna(how="any")
df_credit_req.sample(5)
# Out:
#            sexo tipo_de_emprendimiento       idea_negocio  \
# 3353  masculino               servicio        restaurante
# 1759   femenino               servicio          panaderia
# 1383   femenino              industria        fabrica de
# 7673   femenino               comercio  distribuidora de
# 829    femenino               servicio        restaurante
#
#                      barrio  estrato  comuna_ciudadano fecha_de_beneficio  \
# 3353            santa lucia        3              12.0         15/01/2019
# 1759  cabecera san antonio         2              80.0         26/08/2016
# 1383              belencito        2              13.0          8/02/2018
# 7673                robledo        2               7.0         22/11/2016
# 829                aranjuez        3               4.0          1/12/2016
#
#      monto_del_credito     línea_credito
# 3353           4000000  microempresarial
# 1759           6000000  Microempresarial
# 1383           7370000  microempresarial
# 7673           4000000  microempresarial
# 829            4000000  microempresarial

# %%
for col in df_credit_req.columns:
    print(f"=== Frecuencias de '{col}' ===")
    print(df_credit_req[col].value_counts(dropna=False)) 
    print("\n" + "="*40 + "\n")
# Out:
# === Frecuencias de 'sexo' ===
# sexo
# femenino     6660
# masculino    3627
# FEMENINO      161
# Femenino      117
# MASCULINO      85
# Masculino      66
# Name: count, dtype: int64
#
# ========================================
#
# === Frecuencias de 'tipo_de_emprendimiento' ===
# tipo_de_emprendimiento
# comercio        5697
# servicio        2227
# industria       2214
# COMERCIO         173
# agropecuaria     169
# INDUSTRIA         75
# Comercio          55
# SERVICIO          54
# Servicio          27
# Industria         20
# AGROPECUARIA       5
# Name: count, dtype: int64
#
# ========================================
#
# === Frecuencias de 'idea_negocio' ===
# idea_negocio
# fabrica de              1724
# variedades              1668
# tienda                   974
# comidas rapidas          891
# peluqueria               572
#                         ...
# Venta De Lacteos           1
# Lavadero De                1
# fabrica_de_colchones       1
# viveros_                   1
# Gimnasio                   1
# Name: count, Length: 211, dtype: int64
#
# ========================================
#
# === Frecuencias de 'barrio' ===
# barrio
# robledo                   992
# manrique central no. 1    471
# san javier no.1           411
# aranjuez                  381
# belen                     377
#                          ...
# LA FRANCIA                  1
# LA AMERICA                  1
# suburbano barro             1
# el estadio                  1
# el llano                    1
# Name: count, Length: 428, dtype: int64
#
# ========================================
#
# === Frecuencias de 'estrato' ===
# estrato
# 2    5269
# 3    3293
# 1    2151
# 0       3
# Name: count, dtype: int64
#
# ========================================
#
# === Frecuencias de 'comuna_ciudadano' ===
# comuna_ciudadano
# 4.0     1400
# 7.0     1179
# 9.0     1020
# 13.0     881
# 1.0      877
# 8.0      763
# 5.0      693
# 2.0      666
# 3.0      613
# 6.0      589
# 16.0     441
# 60.0     409
# 10.0     306
# 80.0     280
# 12.0     241
# 15.0     207
# 90.0      70
# 70.0      30
# 50.0      27
# 11.0      12
# 14.0      12
# Name: count, dtype: int64
#
# ========================================
#
# === Frecuencias de 'fecha_de_beneficio' ===
# fecha_de_beneficio
# 3/10/2018     62
# 11/10/2018    57
# 14/09/2018    41
# 24/09/2018    39
# 25/04/2018    38
#               ..
# 2016/01/28     1
# 2017/12/11     1
# 2018/05/10     1
# 2017/10/11     1
# 2018/04/12     1
# Name: count, Length: 1224, dtype: int64
#
# ========================================
#
# === Frecuencias de 'monto_del_credito' ===
# monto_del_credito
# 7800000     1167
# 7000000     1054
# 5000000     1035
# 6000000      946
# 4000000      759
#             ...
# 22131510       1
# 7320000        1
# 4850000        1
# 8261160        1
# 80000000       1
# Name: count, Length: 332, dtype: int64
#
# ========================================
#
# === Frecuencias de 'línea_credito' ===
# línea_credito
# microempresarial          9999
# Microempresarial           349
# MICROEMPRESARIAL           172
# empresarial ed.             68
# agropecuaria                57
# juridica y cap.semilla      30
# credioportuno               21
# fomento agropecuario         5
# Agropecuaria                 3
# empresarial-ed.-             2
# soli-diaria                  2
# Juridica Y Cap.Semilla       2
# juridica_y_cap.semilla       2
# EMPRESARIAL ED.              1
# solidaria                    1
# ayacucho formal              1
# empresarial_ed._             1
# Name: count, dtype: int64
#
# ========================================

# %%
def clean_string(s: str):
    tmp = s.upper()
    ans = tmp.replace("_", " ").replace(".", " ").replace("-", " ")
    return " ".join(ans.split()).strip()

# %%
df_clean = df_credit_req.copy().dropna()
# Limpieza de columna 'sexo'
df_clean["sexo"] = df_clean["sexo"].str.upper().astype("category")
# Limpieza de columna 'tipo_de_emprendimiento'
df_clean["tipo_de_emprendimiento"] = df_clean["tipo_de_emprendimiento"].apply(clean_string).astype("category")
# Limpieza de columna 'monto_del_credito'
df_clean["monto_del_credito"] = df_clean["monto_del_credito"].str.removeprefix("$ ").str.replace(",", "").astype("float")
# Limpieza de columna 'estrato'
df_clean["estrato"] = df_clean["estrato"].astype("category")
# Limpieza de columna 'barrio'
df_clean["barrio"] = df_clean["barrio"].str.upper().str.replace("_", " ").str.replace("-", " ").astype("category")
# Limpieza de columna 'idea_negocio'
df_clean["idea_negocio"] = df_clean["idea_negocio"].apply(clean_string).astype("category")
# Limpieza columna 'comuna_ciudadano'
df_clean["comuna_ciudadano"] = df_clean["comuna_ciudadano"].astype(int).astype("category")
# Limpieza columna 'línea_credito'
df_clean["línea_credito"] = df_clean["línea_credito"].apply(clean_string).astype("category")
# Limpieza columna 'fecha_de_beneficio'
df_clean["fecha_de_beneficio"] = pd.to_datetime(df_clean['fecha_de_beneficio'], dayfirst=True, format="mixed")

# %%
df_clean.drop_duplicates(inplace=True)
df_clean.sample(5)
# Out:
#            sexo tipo_de_emprendimiento idea_negocio           barrio estrato  \
# 1642   FEMENINO               SERVICIO   PELUQUERIA         ARANJUEZ       3
# 7123   FEMENINO               SERVICIO   PELUQUERIA  VILLA GUADALUPE       2
# 847   MASCULINO               COMERCIO       TIENDA     BUENOS AIRES       3
# 413    FEMENINO              INDUSTRIA   FABRICA DE        ANDALUCIA       2
# 6800  MASCULINO               SERVICIO   VARIEDADES   BARRIO CAICEDO       2
#
#      comuna_ciudadano fecha_de_beneficio  monto_del_credito     línea_credito
# 1642                4         2017-03-27          3500000.0  MICROEMPRESARIAL
# 7123                1         2017-08-01          7000000.0  MICROEMPRESARIAL
# 847                 9         2019-04-10          8281000.0  MICROEMPRESARIAL
# 413                 2         2018-07-11          1500000.0  MICROEMPRESARIAL
# 6800                9         2017-07-07          7377000.0  MICROEMPRESARIAL

# %%
df_clean.to_csv('../files/output/solicitudes_de_credito.csv', sep=';', index=False)
